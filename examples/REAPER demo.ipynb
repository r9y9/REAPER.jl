# %%
using REAPER
using PyPlot
# Out:
# INFO: Loading help data...

# %%
x = int16(vec(readdlm(joinpath(Pkg.dir("REAPER"), "test", "test16k.txt"))))
fs = 16000
time_axis = [1:length(x)]/fs
figure(figsize=(16, 6), dpi=80, facecolor="w", edgecolor="k")
plot(time_axis, x, label="a speech signal")
xlim(time_axis[1], time_axis[end])
xlabel("Time [sec]")
legend()
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f0e3cb3dd10>)
# PyObject <matplotlib.legend.Legend object at 0x7f0e5eb924d0>

# %%
pm_times, pm, f0_times, f0, corr = reaper(x, fs);
# Out:
# Residual symmetry: P:1814.794312  N:2462.929688  MEAN:0.243403

# %%
figure(figsize=(16, 6), dpi=80, facecolor="w", edgecolor="k")
plot(pm_times, pm, label="Pitch mark", linewidth=2, color=:magenta)
xlabel("Time [sec]")
xlim(pm_times[1], pm_times[end])
legend()
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f0e5eb07490>)
# PyObject <matplotlib.legend.Legend object at 0x7f0e3c22a0d0>

# %%
figure(figsize=(16, 6), dpi=80, facecolor="w", edgecolor="k")
plot(f0_times, f0, label="F0 trajectory", linewidth=2, color=:green)
xlabel("Time [sec]")
xlim(f0_times[1], f0_times[end])
legend()
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f0e3c247c10>)
# PyObject <matplotlib.legend.Legend object at 0x7f0e3c1c2f50>

# %%
figure(figsize=(16, 6), dpi=80, facecolor="w", edgecolor="k")
plot(f0_times, corr, label="Correlation function", linewidth=2, color=:purple)
xlabel("Time [sec]")
xlim(f0_times[1], f0_times[end])
legend()
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f0e5eaa3710>)
# PyObject <matplotlib.legend.Legend object at 0x7f0e3c092d90>
